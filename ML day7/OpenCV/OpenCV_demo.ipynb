# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("download.jpg")   

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

blur = cv2.GaussianBlur(gray, (5, 5), 0)

edges = cv2.Canny(blur, 100, 200)



plt.figure(figsize=(12,6))

plt.subplot(1,4,1)
plt.imshow(image_rgb)
plt.title("Original")
plt.axis("off")

plt.subplot(1,4,2)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale")
plt.axis("off")

plt.subplot(1,4,3)
plt.imshow(blur, cmap='gray')
plt.title("Blur")
plt.axis("off")

plt.subplot(1,4,4)
plt.imshow(edges, cmap='gray')
plt.title("Edges")
plt.axis("off")

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("pan_card.png")   

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

blur = cv2.GaussianBlur(gray, (5, 5), 0)

edges = cv2.Canny(blur, 100, 200)



plt.figure(figsize=(12,6))

plt.subplot(1,4,1)
plt.imshow(image_rgb)
plt.title("Original")
plt.axis("off")

plt.subplot(1,4,2)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale")
plt.axis("off")

plt.subplot(1,4,3)
plt.imshow(blur, cmap='gray')
plt.title("Blur")
plt.axis("off")

plt.subplot(1,4,4)
plt.imshow(edges, cmap='gray')
plt.title("Edges")
plt.axis("off")

plt.show()

# %%
# !pip install opencv-python
# !pip install pytesseract
# Out:
# Requirement already satisfied: opencv-python in c:\users\administrator\appdata\local\programs\python\python314\lib\site-packages (4.13.0.90)
# Requirement already satisfied: numpy>=2 in c:\users\administrator\appdata\local\programs\python\python314\lib\site-packages (from opencv-python) (2.4.1)
# Requirement already satisfied: pytesseract in c:\users\administrator\appdata\local\programs\python\python314\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in c:\users\administrator\appdata\roaming\python\python314\site-packages (from pytesseract) (26.0)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\administrator\appdata\local\programs\python\python314\lib\site-packages (from pytesseract) (12.1.0)

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
image = cv2.imread("pan_card.png")
extracted_text = pytesseract.image_to_string(image)

print("Extracted Text:")
print(extracted_text)
# Out:
# Extracted Text:
# staat fest AIA Wee
#
# INCOMETAX DEPARTMENT Gl GOVT. OF INDIA
# cee pe
# ane Account Number Ca
# pseperzsar | GlaraLsl
#
# aH Name
# APPLICANT NAME
#
# ‘eta Father's Nam
# APPLICANT'S FATHER NAME
#
# estan!
