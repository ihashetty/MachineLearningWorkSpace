# %%
import numpy as np
import pandas as pd

df=pd.read_csv('data1.csv')
print(df)

print(df.describe())
print(df.shape)
print(df.head(3))
print("string\n",df.to_string(max_rows=4, max_cols=4))
# Out:
#    emp_id         name  age  department         designation        salary  \
# 0     101  Amit Sharma   28           1   Software Engineer  66000.000000
# 1     102   Riya Verma   32           3          HR Manager  66000.000000
# 2     103  Rahul Mehta   28           1   Backend Developer  67028.571429
# 3     104   Sneha Iyer   35           2          Accountant  74750.000000
# 4     105  Arjun Singh   35           4     Sales Executive  45000.000000
# 5     106   Neha Gupta   32           1  Frontend Developer  62400.000000
# 6     107   Vikram Rao   38           5  Operations Manager  72000.000000
# 7     108   Pooja Nair   28           3        HR Executive  46200.000000
#
#    experience       city  bonus
# 0           4  Bangalore   5000
# 1           8      Delhi   5000
# 2           3       Pune   5000
# 3          10    Chennai   5000
# 4           5     Mumbai   5000
# 5           6  Bangalore   5000
# 6          14  Hyderabad   5000
# 7           2      Kochi   5000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   emp_id       8 non-null      int64
#  1   name         8 non-null      object
#  2   age          8 non-null      int64
#  3   department   8 non-null      int64
#  4   designation  8 non-null      object
#  5   salary       8 non-null      float64
#  6   experience   8 non-null      int64
#  7   city         8 non-null      object
#  8   bonus        8 non-null      int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 708.0+ bytes

# %%
print(df[["salary","age"]])
# Out:
#          salary  age
# 0  66000.000000   28
# 1  66000.000000   32
# 2  67028.571429   28
# 3  74750.000000   35
# 4  45000.000000   35
# 5  62400.000000   32
# 6  72000.000000   38
# 7  46200.000000   28

# %%
print(df[(df["salary"]>50000) & (df["department"]=="IT")])
print(df[df["salary"]>50000].shape[0])
# Out:
# Empty DataFrame
# Columns: [emp_id, name, age, department, designation, salary, experience, city, bonus]
# Index: []
# 6

# %%
print(df.sort_values(by="salary", ascending=False))
# Out:
#    emp_id         name  age  department         designation        salary  \
# 3     104   Sneha Iyer   35           2          Accountant  74750.000000
# 6     107   Vikram Rao   38           5  Operations Manager  72000.000000
# 2     103  Rahul Mehta   28           1   Backend Developer  67028.571429
# 1     102   Riya Verma   32           3          HR Manager  66000.000000
# 0     101  Amit Sharma   28           1   Software Engineer  66000.000000
# 5     106   Neha Gupta   32           1  Frontend Developer  62400.000000
# 7     108   Pooja Nair   28           3        HR Executive  46200.000000
# 4     105  Arjun Singh   35           4     Sales Executive  45000.000000
#
#    experience       city  bonus
# 3          10    Chennai   5000
# 6          14  Hyderabad   5000
# 2           3       Pune   5000
# 1           8      Delhi   5000
# 0           4  Bangalore   5000
# 5           6  Bangalore   5000
# 7           2      Kochi   5000
# 4           5     Mumbai   5000

# %%
print(df["salary"].sum())
# Out:
# 499378.5714285714

# %%
print(df.groupby("city").size())
# Out:
# city
# Bangalore    2
# Chennai      1
# Delhi        1
# Hyderabad    1
# Kochi        1
# Mumbai       1
# Pune         1
# dtype: int64

# %%
print(df[df["salary"].isnull()])
# Out:
# Empty DataFrame
# Columns: [emp_id, name, age, department, designation, salary, experience, city, bonus]
# Index: []

# %%
print(df["salary"].mean())
print(df.index)
# Out:
# 62422.32142857143
# RangeIndex(start=0, stop=8, step=1)

# %%
df.fillna(df["salary"].mean(), inplace=True)
print(df)
# Out:
#    emp_id         name  age  department         designation        salary  \
# 0     101  Amit Sharma   28           1   Software Engineer  66000.000000
# 1     102   Riya Verma   32           3          HR Manager  66000.000000
# 2     103  Rahul Mehta   28           1   Backend Developer  67028.571429
# 3     104   Sneha Iyer   35           2          Accountant  74750.000000
# 4     105  Arjun Singh   35           4     Sales Executive  45000.000000
# 5     106   Neha Gupta   32           1  Frontend Developer  62400.000000
# 6     107   Vikram Rao   38           5  Operations Manager  72000.000000
# 7     108   Pooja Nair   28           3        HR Executive  46200.000000
#
#    experience       city  bonus
# 0           4  Bangalore   5000
# 1           8      Delhi   5000
# 2           3       Pune   5000
# 3          10    Chennai   5000
# 4           5     Mumbai   5000
# 5           6  Bangalore   5000
# 6          14  Hyderabad   5000
# 7           2      Kochi   5000

# %%
df['bonus']=5000
print(df)
# Out:
#    emp_id         name  age  department         designation        salary  \
# 0     101  Amit Sharma   28           1   Software Engineer  66000.000000
# 1     102   Riya Verma   32           3          HR Manager  66000.000000
# 2     103  Rahul Mehta   28           1   Backend Developer  67028.571429
# 3     104   Sneha Iyer   35           2          Accountant  74750.000000
# 4     105  Arjun Singh   35           4     Sales Executive  45000.000000
# 5     106   Neha Gupta   32           1  Frontend Developer  62400.000000
# 6     107   Vikram Rao   38           5  Operations Manager  72000.000000
# 7     108   Pooja Nair   28           3        HR Executive  46200.000000
#
#    experience       city  bonus
# 0           4  Bangalore   5000
# 1           8      Delhi   5000
# 2           3       Pune   5000
# 3          10    Chennai   5000
# 4           5     Mumbai   5000
# 5           6  Bangalore   5000
# 6          14  Hyderabad   5000
# 7           2      Kochi   5000

# %%
df.loc[df['department']=='HR', 'salary'] *= 1.1
df.loc[df['department']=='IT', 'salary'] *= 1.2
df.loc[df['department']=='Finance', 'salary'] *= 1.15
print(df)
# Out:
#    emp_id         name  age  department         designation        salary  \
# 0     101  Amit Sharma   28           1   Software Engineer  66000.000000
# 1     102   Riya Verma   32           3          HR Manager  66000.000000
# 2     103  Rahul Mehta   28           1   Backend Developer  67028.571429
# 3     104   Sneha Iyer   35           2          Accountant  74750.000000
# 4     105  Arjun Singh   35           4     Sales Executive  45000.000000
# 5     106   Neha Gupta   32           1  Frontend Developer  62400.000000
# 6     107   Vikram Rao   38           5  Operations Manager  72000.000000
# 7     108   Pooja Nair   28           3        HR Executive  46200.000000
#
#    experience       city  bonus
# 0           4  Bangalore   5000
# 1           8      Delhi   5000
# 2           3       Pune   5000
# 3          10    Chennai   5000
# 4           5     Mumbai   5000
# 5           6  Bangalore   5000
# 6          14  Hyderabad   5000
# 7           2      Kochi   5000

# %%
df['department'] = df['department'].replace('Operations',5)
print(df)
df.to_csv('data1.csv', index=False)
# Out:
#    emp_id         name  age  department         designation        salary  \
# 0     101  Amit Sharma   28           1   Software Engineer  66000.000000
# 1     102   Riya Verma   32           3          HR Manager  66000.000000
# 2     103  Rahul Mehta   28           1   Backend Developer  67028.571429
# 3     104   Sneha Iyer   35           2          Accountant  74750.000000
# 4     105  Arjun Singh   35           4     Sales Executive  45000.000000
# 5     106   Neha Gupta   32           1  Frontend Developer  62400.000000
# 6     107   Vikram Rao   38           5  Operations Manager  72000.000000
# 7     108   Pooja Nair   28           3        HR Executive  46200.000000
#
#    experience       city  bonus
# 0           4  Bangalore   5000
# 1           8      Delhi   5000
# 2           3       Pune   5000
# 3          10    Chennai   5000
# 4           5     Mumbai   5000
# 5           6  Bangalore   5000
# 6          14  Hyderabad   5000
# 7           2      Kochi   5000

# %%
df1=pd.read_csv('dept.csv')
print(df1)

df=df.merge(df1, on='department', how='left')
print(df)

df2=pd.merge(df, df1, left_on='department', right_on='department')
print(df2)
# Out:
#    department department name
# 0           1              IT
# 1           2         Finance
# 2           3              HR
# 3           4           Sales
# 4           5      Operations
#    emp_id         name  age  department         designation        salary  \
# 0     101  Amit Sharma   28           1   Software Engineer  66000.000000
# 1     102   Riya Verma   32           3          HR Manager  66000.000000
# 2     103  Rahul Mehta   28           1   Backend Developer  67028.571429
# 3     104   Sneha Iyer   35           2          Accountant  74750.000000
# 4     105  Arjun Singh   35           4     Sales Executive  45000.000000
# 5     106   Neha Gupta   32           1  Frontend Developer  62400.000000
# 6     107   Vikram Rao   38           5  Operations Manager  72000.000000
# 7     108   Pooja Nair   28           3        HR Executive  46200.000000
#
#    experience       city  bonus department name
# 0           4  Bangalore   5000              IT
# ...

# %%
import matplotlib.pyplot as plt
plt.bar(df['experience'], df['salary'])
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Experience vs Salary')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df['salary'], bins=10, color='blue', alpha=1)
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Salary Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(df['salary'], df['age'],color='green', marker='o', linestyle='None', alpha=0.7)
plt.xlabel('Salary')
plt.ylabel('Age')
plt.title('Salary vs Age')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['salary'], df['age'], color='green', alpha=0.7)
plt.xlabel('Salary')
plt.ylabel('Age')
plt.title('Salary vs Age')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.pie(
    df['salary'],
    labels=df['age'],
    autopct=lambda pct: f'{int(round(pct/100 * df["salary"].sum(), 0))}'
)
plt.title('Salary vs Age')
plt.show()

# %%
plt.bar(df["age"], df["salary"])
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary")
plt.show()

# %%
arr = df["age"].value_counts()
plt.scatter(arr.index, arr.values)
plt.xlabel("Counts")
plt.ylabel("Age")
plt.title("Age vs Counts")
plt.show()

# %%
arr = df["city"].value_counts()
plt.scatter(arr.index, arr.values)
plt.xlabel("City")
plt.ylabel("Counts")
plt.title("City vs Counts")
plt.show()

# %%
arr = df["city"].value_counts()
print(type(arr.values[0]))
plt.scatter(arr.index, arr.values)
plt.yticks(range(0,6))
plt.xlabel("City")
plt.ylabel("Counts")
plt.title("City vs Counts")
plt.show()
# Out:
# <class 'numpy.int64'>

# %%
import seaborn as sns
sns.barplot(data=df,x="experience",y="salary")
# Out:
# <Axes: xlabel='experience', ylabel='salary'>

# %%
sns.scatterplot(data=df,x="experience",y="salary", hue="department")
# Out:
# <Axes: xlabel='experience', ylabel='salary'>
